# %%
# !pip install -U pandas
# !pip install -U sklearn
# !pip install -U openpyxl
# !pip install -U imbalanced-learn
# Out:
# Requirement already up-to-date: pandas in /home/admin/venv-jupyter/lib/python3.7/site-packages (1.0.3)
# ...
# Requirement already up-to-date: sklearn in /home/admin/venv-jupyter/lib/python3.7/site-packages (0.0)
# ...
# Requirement already up-to-date: openpyxl in /home/admin/venv-jupyter/lib/python3.7/site-packages (3.0.3)
# ...
# Requirement already up-to-date: imbalanced-learn in /home/admin/venv-jupyter/lib/python3.7/site-packages (0.6.2)
# ...

# %%
import pandas as pd 
import sys
from sklearn.svm import LinearSVC
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.feature_extraction.text import TfidfVectorizer

import classifier_tool as tool

# %%
label = 'angin_topan'
rep_list = [
    't_lower', 'c_lower', 'tc_lower',
    't_swrem', 'c_swrem', 'tc_swrem',
    't_stem', 'c_stem', 'tc_stem',
    't_swrem_stem', 'c_swrem_stem', 'tc_swrem_stem',
]
#f_in = '/home/admin/text_processing/anotated_data/preprocessed/' + label + '_anotated.json'
f_oz = '/home/admin/text_processing/anotated_data/from_anotators/yandi/sample_angin_topan_20200414_yandi_20200417_fixed_pre.json'
f_yn = '/home/admin/text_processing/anotated_data/from_anotators/ozy/sample_angin_topan_20200414_ozy_20200421_fixed_pre.json'
df_oz = pd.read_json(f_oz)
df_yn = pd.read_json(f_yn)

# %%
df_corpus = df_oz.rename(columns={'label' : 'label_oz'})    
df_corpus['label_yn'] = df_yn['label']
df = df_corpus[df_corpus.label_oz == df_corpus.label_yn]
df = df.rename(columns={'label_oz' : 'label'})
df = df.drop(columns='label_yn')
df = df.reset_index(drop=True)

# %%
def test_rep(rep, df, clf, fold=10):
    X = tool.construct_tfidf_unigrams(df[rep])
    y = df['label']
    report = tool.eval_cv(fold, X, y, clf)
    y_report = [ d['Y'] for d in report ]
    n_report = [ d['N'] for d in report ]
   
    df_y = pd.DataFrame(y_report)
    df_n = pd.DataFrame(n_report)
    df_y.loc['avg'] = df_y.mean()
    df_n.loc['avg'] = df_n.mean()
    df_y_avg = df_y.loc[['avg']]
    df_y_avg = df_y_avg.rename(columns={'precision' : 'y_prec', 'recall':'y_recall', 'f1-score' : 'y_f1', 'support' : 'y_support'})
   
    return df_y_avg, df_y, df_n

# %%
#clf = SVC()
#df_summary = pd.DataFrame()
#for rep in rep_list:
#    df_y_avg, df_y, df_n = test_rep(rep, df, clf)
#    df_summary[rep] = df_y_avg.loc['avg']

# %%
#df_summary

# %%
list_id = [
'angin_topan_0002','angin_topan_0016','angin_topan_0022','angin_topan_0023','angin_topan_0026',
'angin_topan_0027','angin_topan_0029','angin_topan_0031','angin_topan_0038','angin_topan_0040',
'angin_topan_0050','angin_topan_0052','angin_topan_0053','angin_topan_0058','angin_topan_0063',
'angin_topan_0065','angin_topan_0072','angin_topan_0088','angin_topan_0090','angin_topan_0093',
'angin_topan_0098','angin_topan_0108','angin_topan_0109','angin_topan_0110','angin_topan_0114',
'angin_topan_0120','angin_topan_0127','angin_topan_0134','angin_topan_0136','angin_topan_0140',
'angin_topan_0155','angin_topan_0163','angin_topan_0166','angin_topan_0206','angin_topan_0207',
'angin_topan_0220','angin_topan_0222','angin_topan_0224','angin_topan_0228','angin_topan_0242',
'angin_topan_0244','angin_topan_0250','angin_topan_0251','angin_topan_0258','angin_topan_0260',
'angin_topan_0270','angin_topan_0272','angin_topan_0283','angin_topan_0286','angin_topan_0295',
'angin_topan_0299','angin_topan_0302','angin_topan_0310','angin_topan_0315','angin_topan_0339',
'angin_topan_0347','angin_topan_0352','angin_topan_0364','angin_topan_0382','angin_topan_0391',
'angin_topan_0429','angin_topan_0435','angin_topan_0440','angin_topan_0450','angin_topan_0452',
'angin_topan_0457','angin_topan_0458','angin_topan_0460','angin_topan_0463','angin_topan_0473',
'angin_topan_0492','angin_topan_0493','angin_topan_0500','angin_topan_0507','angin_topan_0524',
'angin_topan_0529','angin_topan_0534','angin_topan_0535','angin_topan_0550','angin_topan_0570',
'angin_topan_0576','angin_topan_0577','angin_topan_0588','angin_topan_0620','angin_topan_0623',
'angin_topan_0624','angin_topan_0656','angin_topan_0660','angin_topan_0666','angin_topan_0671',
'angin_topan_0677','angin_topan_0690','angin_topan_0692','angin_topan_0695','angin_topan_0702',
'angin_topan_0713','angin_topan_0718','angin_topan_0728','angin_topan_0731','angin_topan_0732',
'angin_topan_0737','angin_topan_0739','angin_topan_0771','angin_topan_0782','angin_topan_0798',
'angin_topan_0812','angin_topan_0816','angin_topan_0817','angin_topan_0819','angin_topan_0827',
'angin_topan_0833','angin_topan_0842','angin_topan_0852','angin_topan_0863','angin_topan_0872',
'angin_topan_0873','angin_topan_0876','angin_topan_0878','angin_topan_0879','angin_topan_0889',
'angin_topan_0899','angin_topan_0905','angin_topan_0906','angin_topan_0907','angin_topan_0909',
'angin_topan_0912','angin_topan_0922','angin_topan_0938','angin_topan_0951','angin_topan_0952',
'angin_topan_0953','angin_topan_0954','angin_topan_0958','angin_topan_0963','angin_topan_0983',
'angin_topan_0985','angin_topan_0996','angin_topan_1026','angin_topan_1027','angin_topan_1036',
'angin_topan_1057','angin_topan_1071','angin_topan_1105','angin_topan_1108','angin_topan_1112',
'angin_topan_1113','angin_topan_1114','angin_topan_1125','angin_topan_1126','angin_topan_1145',
'angin_topan_1147','angin_topan_1155','angin_topan_1156','angin_topan_1170','angin_topan_1173',
'angin_topan_1180','angin_topan_1204','angin_topan_1210',
]
print(len(list_id))
# Out:
# 158

# %%
df_train = df

# %%
X_train, vectorizer = tool.construct_tfidf_unigrams(df_train['tc_swrem_stem'])
y_train = df_train['label']

# %%
from imblearn.over_sampling import SMOTE
ros = SMOTE()
X_resampled, y_resampled = ros.fit_resample(X_train, y_train)

# %%
clf_new = SVC()
clf_new.fit(X_train, y_train)
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
#df['reports'].isin(numbers)
df_new = df_corpus[df_corpus.id.isin(list_id)]
df_new = df_new.reset_index(drop=True)

# %%
X_new = vectorizer.transform(df_new['t_swrem_stem'])
X_new.shape
# Out:
# (158, 18605)

# %%
res  = clf_new.predict(X_new)

# %%
res_y = [ e for e in res if e == 'Y' ]
res_n = [ e for e in res if e == 'N' ]
print('Y : {:d}, N: {:d}'.format(len(res_y), len(res_n)))
# Out:
# Y : 12, N: 146

# %%
df_new['label_ml'] = res.tolist()

# %%
f_excel_out_diff = '/home/admin/text_processing/anotated_data/from_anotators/angin_topan_diff.xlsx'
df_new.to_excel(f_excel_out_diff, index=False)

# %%
f_man = '/home/admin/text_processing/anotated_data/from_anotators/fixing/angin_topan_diff_with_ml_and_manual.xlsx'
df_man = pd.read_excel(f_man)

# %%
df_man
# Out:
#                    id             source                               date  \
# 0    angin_topan_0002  aceh_harianrakyat                  November 11, 2016
# 1    angin_topan_0016  aceh_harianrakyat                   October 15, 2018
# 2    angin_topan_0022        aceh_tribun         Senin, 20 April 2015 17:15
# 3    angin_topan_0023        aceh_tribun          Minggu, 7 Juni 2015 13:42
# 4    angin_topan_0026        aceh_tribun        Jumat, 3 Januari 2020 16:06
# ..                ...                ...                                ...
# 153  angin_topan_1170      sumsel_tribun       Sabtu, 27 Oktober 2018 17:12
# 154  angin_topan_1173           sumut_go    Selasa, 28 Maret 2017 19:30 WIB
# 155  angin_topan_1180           sumut_go  Rabu, 14 September 2016 14:34 WIB
# 156  angin_topan_1204    surabaya_tribun        Senin, 6 Januari 2020 19:12
# 157  angin_topan_1210    surabaya_tribun       Senin, 9 Desember 2019 20:10
#
# ...

# %%
df_corpus['final_label'] = df_corpus['label_yn']
df_man
# Out:
#                    id             source                               date  \
# 0    angin_topan_0002  aceh_harianrakyat                  November 11, 2016
# 1    angin_topan_0016  aceh_harianrakyat                   October 15, 2018
# 2    angin_topan_0022        aceh_tribun         Senin, 20 April 2015 17:15
# 3    angin_topan_0023        aceh_tribun          Minggu, 7 Juni 2015 13:42
# 4    angin_topan_0026        aceh_tribun        Jumat, 3 Januari 2020 16:06
# ..                ...                ...                                ...
# 153  angin_topan_1170      sumsel_tribun       Sabtu, 27 Oktober 2018 17:12
# 154  angin_topan_1173           sumut_go    Selasa, 28 Maret 2017 19:30 WIB
# 155  angin_topan_1180           sumut_go  Rabu, 14 September 2016 14:34 WIB
# 156  angin_topan_1204    surabaya_tribun        Senin, 6 Januari 2020 19:12
# 157  angin_topan_1210    surabaya_tribun       Senin, 9 Desember 2019 20:10
#
# ...

# %%
for n_id in df_man['id']:
    df_corpus.loc[(df_corpus.id == n_id), 'final_label'] = df_man.loc[(df_man.id == n_id), 'Label Manual'].values

f_fin = '/home/admin/text_processing/anotated_data/from_anotators/fixing/angin_topan_diff_with_ml_and_manual_final.xlsx'
df_corpus.to_excel(f_fin, index=False)
